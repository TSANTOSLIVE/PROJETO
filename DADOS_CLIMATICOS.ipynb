# %%
import pandas as pd
dados_porto_alegre  = pd.read_csv('CSV/PORTO_ALEGRE.csv', sep=',', encoding="ISO-8859-1", decimal=',')

# %%
dados_porto_alegre
# Out:
#       Mês  Dia  Hora TBS {C} TBU {C} T. Pto Orvalho {C}  \
# 0       1    1     1    22.5    18.7               16.5
# 1       1    1     2    21.8    18.3               16.2
# 2       1    1     3    20.5    17.5               15.6
# 3       1    1     4    20.2    17.1               15.1
# 4       1    1     5    19.7    16.8               14.9
# ...   ...  ...   ...     ...     ...                ...
# 8755   12   31    20    29.8    23.8               21.2
# 8756   12   31    21    27.8    23.2               21.1
# 8757   12   31    22    26.0    22.5               20.8
# 8758   12   31    23    25.0    22.2               20.7
# 8759   12   31    24    23.8    21.7               20.5
#
#      Pressao Atmosferica {kPa} Umidade {kg/kg}  U. R. {%}  \
# 0                        100.7     0.012020695         70
# 1                        100.6     0.011816209         72
# 2                        100.6     0.011361026         75
# ...
